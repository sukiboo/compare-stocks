# %% [markdown]
# # Visualize Option Prices

# %%
# %pip -q install ipympl
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib ipympl

# %%
from utlis import plot_option_matrix, plot_option_matrix_3d  # noqa: F401

from options import OptionPrices

ticker = "TQQQ"
opt = OptionPrices(ticker)

# %%
opt.calls
# Out:
#           contractSymbol expirationDate  strikePrice  bidPrice  askPrice  \
# 0    TQQQ250103C00045000     2025-01-03         45.0     32.50     36.40
# 1    TQQQ250103C00050000     2025-01-03         50.0     27.70     30.90
# 2    TQQQ250103C00055000     2025-01-03         55.0     22.65     26.65
# 3    TQQQ250103C00060000     2025-01-03         60.0     18.10     21.00
# 4    TQQQ250103C00065000     2025-01-03         65.0     12.70     15.75
# ..                   ...            ...          ...       ...       ...
# 676  TQQQ270115C00110000     2027-01-15        110.0     15.20     16.80
# 677  TQQQ270115C00115000     2027-01-15        115.0     14.75     16.95
# 678  TQQQ270115C00120000     2027-01-15        120.0     13.65     14.10
# 679  TQQQ270115C00125000     2027-01-15        125.0     12.80     13.65
# 680  TQQQ270115C00130000     2027-01-15        130.0     11.65     12.20
#
#      optionPrice  profitPrice  profitChange
# 0         34.450       79.450     -0.003574
# ...

# %%
opt.puts
# Out:
#           contractSymbol expirationDate  strikePrice  bidPrice  askPrice  \
# 0    TQQQ250103P00045000     2025-01-03         45.0      0.00      0.03
# 1    TQQQ250103P00050000     2025-01-03         50.0      0.00      0.02
# 2    TQQQ250103P00055000     2025-01-03         55.0      0.00      0.03
# 3    TQQQ250103P00060000     2025-01-03         60.0      0.00      0.03
# 4    TQQQ250103P00065000     2025-01-03         65.0      0.01      0.02
# ..                   ...            ...          ...       ...       ...
# 638  TQQQ270115P00110000     2027-01-15        110.0     40.70     42.95
# 639  TQQQ270115P00115000     2027-01-15        115.0     43.95     46.45
# 640  TQQQ270115P00120000     2027-01-15        120.0     44.00     49.00
# 641  TQQQ270115P00125000     2027-01-15        125.0     52.15     53.40
# 642  TQQQ270115P00130000     2027-01-15        130.0     55.60     57.90
#
#      optionPrice  profitPrice  profitChange
# 0          0.015       44.985     -0.435819
# ...

# %%
# plot_option_matrix_3d(opt, "calls")
# plot_option_matrix_3d(opt, "puts")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_option_matrix(opt, option_type="calls")
plot_option_matrix(opt, option_type="puts")

# %%
plot_option_matrix(opt, option_type="calls", relative=True)
plot_option_matrix(opt, option_type="puts", relative=True)
