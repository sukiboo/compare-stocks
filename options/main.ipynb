# %% [markdown]
# # Visualize Option Prices

# %%
# %pip -q install ipympl
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib ipympl

# %%
from utlis import plot_option_matrix, plot_option_matrix_3d

from options import OptionPrices

ticker = "TQQQ"
opt = OptionPrices(ticker)

# %%
opt.calls
# Out:
#           contractSymbol expirationDate  strikePrice  bidPrice  askPrice  \
# 0    TQQQ250103C00050000     2025-01-03         50.0     32.00     36.95
# 1    TQQQ250103C00055000     2025-01-03         55.0     27.05     31.95
# 2    TQQQ250103C00060000     2025-01-03         60.0     22.50     26.95
# 3    TQQQ250103C00065000     2025-01-03         65.0     18.55     20.75
# 4    TQQQ250103C00066000     2025-01-03         66.0     17.35     20.55
# ..                   ...            ...          ...       ...       ...
# 621  TQQQ270115C00110000     2027-01-15        110.0     17.00     20.00
# 622  TQQQ270115C00115000     2027-01-15        115.0     15.50     20.50
# 623  TQQQ270115C00120000     2027-01-15        120.0     15.40     16.60
# 624  TQQQ270115C00125000     2027-01-15        125.0     15.00     18.00
# 625  TQQQ270115C00130000     2027-01-15        130.0     13.25     17.00
#
#      optionPrice  profitPrice  profitChange
# 0         34.475       84.475     -0.001773
# 1         29.500       84.500     -0.001477
# 2         24.725       84.725      0.001182
# 3         19.650       84.650      0.000295
# 4         18.950       84.950      0.003840
# ..           ...          ...           ...
# 621       18.500      128.500      0.518464
# 622       18.000      133.000      0.571640
# 623       16.000      136.000      0.607090
# 624       16.500      141.500      0.672083
# 625       15.125      145.125      0.714919
#
# [626 rows x 8 columns]

# %%
opt.puts
# Out:
#           contractSymbol expirationDate  strikePrice  bidPrice  askPrice  \
# 0    TQQQ250103P00045000     2025-01-03         45.0      0.00      0.02
# 1    TQQQ250103P00050000     2025-01-03         50.0      0.00      0.03
# 2    TQQQ250103P00055000     2025-01-03         55.0      0.02      0.03
# 3    TQQQ250103P00060000     2025-01-03         60.0      0.02      0.04
# 4    TQQQ250103P00065000     2025-01-03         65.0      0.01      0.06
# ..                   ...            ...          ...       ...       ...
# 587  TQQQ270115P00110000     2027-01-15        110.0     37.00     42.00
# 588  TQQQ270115P00115000     2027-01-15        115.0     40.50     45.50
# 589  TQQQ270115P00120000     2027-01-15        120.0     44.00     49.00
# 590  TQQQ270115P00125000     2027-01-15        125.0     47.50     52.50
# 591  TQQQ270115P00130000     2027-01-15        130.0     51.00     56.00
#
#      optionPrice  profitPrice  profitChange
# 0          0.010       44.990     -0.468360
# 1          0.015       49.985     -0.409335
# 2          0.025       54.975     -0.350369
# 3          0.030       59.970     -0.291344
# 4          0.035       64.965     -0.232319
# ..           ...          ...           ...
# 587       39.500       70.500     -0.166913
# 588       43.000       72.000     -0.149188
# 589       46.500       73.500     -0.131462
# 590       50.000       75.000     -0.113737
# 591       53.500       76.500     -0.096012
#
# [592 rows x 8 columns]

# %%
plot_option_matrix_3d(opt, "calls")
plot_option_matrix_3d(opt, "puts")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_option_matrix(opt, option_type="calls")
plot_option_matrix(opt, option_type="puts")

# %%
plot_option_matrix(opt, option_type="calls", relative=True)
plot_option_matrix(opt, option_type="puts", relative=True)
